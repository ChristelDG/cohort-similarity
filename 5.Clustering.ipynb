# %% [markdown]
# ## Code to compute the distance between clinical notes :
# The distance is a weighted sum of all EMD per label.
# The EMD is computed similarly as https://nbviewer.org/github/vene/vene.github.io/blob/pelican/content/blog/word-movers-distance-in-python.ipynb
# Inspired from the word mover distance
# Hence the distance computed is basesd on the embeddings distance
#
# EMD distance will be compare with the optimize linear sum assignement function https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.linear_sum_assignment.html
#
#
# ### In this notebook, distance computation is done label by label
# ie : Clustering on the cardiovascular label, infection label, immunitaire label etc...

# %%
import os
import numpy as np
import pandas as pd 
import random
import pickle

import sklearn
from scipy.spatial.distance import cosine
from scipy.stats import hmean
from sklearn.metrics import euclidean_distances
from sklearn.feature_extraction.text import CountVectorizer

import matplotlib.pyplot as plt

import wordcloud

from sklearn.model_selection import train_test_split
from sklearn.metrics import euclidean_distances
from tqdm import tqdm

import random

from pyemd import emd


# file_path = './out/16122021_train_local_annotated_without_neg_par_hyp_fasttext_BERT_embeddings.pkl'

file_path = './out/25012022_train_val_local_annotated_without_neg_par_hyp_Fasttext_BERT_Emb_Lower.pkl'
img_path = "./out/img_annot_all_attributes/"


Embedding = "Fasttext" # should be Fasttext of local_BERT or EDS_BERT
assert Embedding in ('Fasttext', 'local_BERT', 'EDS_BERT')

# %%
from easynmt import EasyNMT, models
# model = EasyNMT('opus-mt')
model_fr_en = EasyNMT(translator = models.AutoModel('../opus-mt-fr-en'))

# %%
# load the dataframe
df = pd.read_pickle(file_path)
df['idx']=range(len(df))
# load the labels for all the terms of the file
labels = set(df['label'])
print('labels', labels)

# load the files 
files = set(df['source'])
# print("number of files", len(files))
# Out:
# labels {'nerveux', 'etatsosy', 'immunitaire', 'peau', 'respiratoire', 'cardiovasculaires', 'femme', 'infections', 'endocriniennes', 'nutritionnelles', 'homme', 'osteomusculaires', 'parasitaires', 'genetique', 'chimiques', 'stomatognathique', 'hemopathies', 'digestif', 'oeil', 'blessures', 'virales', 'tumeur', 'ORL'}

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]


def distance_files_by_lab(file_1, file_2, Embedding, label, Distance_type = 'cosine', verbose = True) :
    """Compute a distance between two clinical notes, based on the embedding of their extracted terms, based on EMD distance
        Args :
        file_1 : name of the first file to compare 
        file_2 : name of the second files (corresponding to another patient or same patient at different time)
        Embedding : type of embedding should be Fasttext or local_BERT or EDS_BERT
        Distance_type : should be "cosine" ou "euclid"
        label : label we want to compute the distance on
        verbose : if True : print detailed information
        
        Outputs: 
        D_N : final distance 
    """

    
    if verbose:
        print(f'\n ----- Computing the distance between {file_1} and {file_2} for label {label}')
    # first get the common dataframe shared by the two files 
    df_reduc = df[(df["source"]== file_1) | (df["source"]== file_2)]
    # get the total number of terms 
    term_tot = len(df_reduc)
    
    # get the set of corresponding labels 
    labels = set(df_reduc['label'])
    if verbose: 
        print('Set of labels for the two patients', labels)
    

    df_patient_1 = df[df["source"]== file_1]
    df_patient_2 = df[df["source"]== file_2]
    
    labels_patient_1 = set(df_patient_1['label'])
    labels_patient_2 = set(df_patient_2['label'])
    
    # check if the label 
    labels_common = labels_patient_1.intersection(labels_patient_2)
  
    if label not in labels_common :
        print(f"this label {label} is not shared byt he two patients {file_1}, {file_2}")
        print("fonction will return a None object")
        return None

    # get the corresponding vocabulary of this label for the two files : 
    Vocab = df_reduc[df_reduc['label']== label]
    vocab_size = len(Vocab)
    if verbose :
        print(f'For the label "{label}", the vocabulary size is', vocab_size)
        
    # convert it to a dict readable for the CountVectorizer function 
    vocab_dict = {}
    j = 0
    for i in Vocab['idx']:
        if Vocab['term'][i] not in vocab_dict.keys():
            vocab_dict[Vocab['term'][i]] = j
            j += 1
        
    # get a representation feature 
    vect = CountVectorizer(vocabulary = vocab_dict, tokenizer = lambda x : [x], lowercase = False)# .fit([d1,d2,d3])
    # print("\n Features:\n","\n".join(vect.get_feature_names()))
        
    # get the terms for each file
    d1 = Vocab[Vocab['source']== file_1]
    term_1 = d1['term'].to_list()
    if verbose:
        print(f'\n terms patient 1 for label {label}\n', term_1)
    
    d2 = Vocab[Vocab['source']== file_2]
    term_2 = d2['term'].to_list()
    if verbose:
        print(f'\n terms patient 2 for label {label}\n', term_2)
    
    # get the corresponding histograms 
    v1_1 = vect.transform(term_1).toarray()
    v_1 = np.sum(v1_1, 0)
    v2_1 = vect.transform(term_2).toarray()
    v_2 = np.sum(v2_1, 0)
    
    # print(v_1, v_2)
    # print("\n cosine(doc_1, doc_2) = {:.2f}".format(cosine(v_1, v_2)))
    
    # get the FastText of BERT_embedding associated  
    idx_w = [Vocab[Vocab['term'] == w].iloc[0].idx for w in vect.get_feature_names()]
    W_2 = []

    for idx in idx_w:
        # print('\n------idx', idx)
        if (Embedding == 'Fasttext'): 
            W_2.append(Vocab['fastext_embeddings'][int(idx)])

        elif Embedding == "local_BERT": 
            W_2.append(Vocab['BERT_embeddings'][int(idx)])
                
    if Distance_type == 'cosine':
        Dist = sklearn.metrics.pairwise.cosine_distances(W_2) # cosine_distance : ie 1-cos similarity = 1-cos(theta)
    if Distance_type == 'euclid':
        Dist = euclidean_distances(W_2)
    
    # distance computation : 
    # pyemd needs double precision input
    v_1 = v_1.astype(np.double)
    v_2 = v_2.astype(np.double)
    
    v_1 /= v_1.sum()
    v_2 /= v_2.sum()
    
    Dist = Dist.astype(np.double)
    if Dist.max() != 0:
        Dist /= Dist.max()  # just for comparison purposes
    D_EMD = emd(v_1, v_2, Dist)
    
             
    if verbose:
        print(f'\nDistance {Distance_type} for label {label} between {file_1} and {file_2} =',D_EMD)
    
    return D_EMD

# %%
# Main_2
# give the corresponding label :
label = "digestif"
# get the file containint the corresponding label : 
df_lab = df[df['label']==label]
files_lab = set(df_lab['source'])
files_lab_l = list(files_lab)

print(f"Computing the distance for label {label}")
# final dict of all distances : 
DIST_l = {}
count = 0

size_DIST = len(files_lab_l)**2
print('size_DIST', size_DIST)


for file_1 in sorted(files_lab):
    for file_2 in sorted(files_lab):
        if ((file_1,file_2) not in DIST_l.keys()) & ((file_2,file_1) not in DIST_l.keys()):
            D_EMD = distance_files_by_lab(file_1, file_2, Embedding,label,
                                          Distance_type = 'cosine', verbose = False)
            # print("D_EMD", D_EMD)
            DIST_l[(file_1,file_2)]= DIST_l[(file_2, file_1)] = D_EMD
            count += 1
            if count%1000 == 0:
                print('count', count)
# Out:
# Computing the distance for label digestif
# size_DIST 7921
# count 1000
# count 2000
# count 3000
# count 4000

# %%
SCL = []
LUPUS = []
TAKA = []
SAPL = []

for i in range(len(files_lab_l)): 
    if 'scl' in files_lab_l[i]:
        SCL.append(files_lab_l[i])
    if 'lupus' in files_lab_l[i]:
        
        LUPUS.append(files_lab_l[i])
    if 'sapl' in files_lab_l[i]:
        SAPL.append(files_lab_l[i])
    if 'taka' in files_lab_l[i]:
        TAKA.append(files_lab_l[i])

dist_TAKA = [DIST_l[(f,g)] for f in TAKA for g in TAKA]
dist_SCL = [DIST_l[(f,g)] for f in SCL for g in SCL]
dist_LUPUS = [DIST_l[(f,g)] for f in LUPUS for g in LUPUS]
dist_SAPL = [DIST_l[(f,g)] for f in SAPL for g in SAPL]

np.mean(dist_TAKA), np.mean(dist_SCL), np.mean(dist_LUPUS), np.mean(dist_SAPL)
# Out:
# (0.8143820018999766,
#  0.7231994525156995,
#  0.8412200721766427,
#  0.7272735558585414)

# %%
dist = [d for k,d in DIST_l.items()]
np.mean(dist)
# Out:
# 0.8010687100602187

# %%
X = np.zeros((len(files_lab_l), len(files_lab_l)))

for i in range(len(files_lab_l)): 
    for j in range(len(files_lab_l)):
        X[i,j] = DIST_l[(files_lab_l[i],files_lab_l[j])]

# %% [markdown]
# # CLUSTERING
# from a Distance matrix :
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html
#
#
# some other info on :
# https://stackoverflow.com/questions/18952587/use-distance-matrix-in-scipy-cluster-hierarchy-linkage

# %%
import scipy.cluster.hierarchy as hcl
from scipy.spatial.distance import squareform
import scipy.spatial.distance as ssd
# convert the redundant n*n square matrix form into a condensed nC2 array
distArray = ssd.squareform(X) # distArray[{n choose 2}-{n-i choose 2} + (j-i-1)] is the distance between points i and j

# hierarchical clustering encoded as a linkage matrix
Z = hcl.linkage(distArray, method = 'ward')

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

labels = files_lab_l

fig = plt.figure(figsize=(25, 10))

plt.title(f"dendogramm_clustering_label_digestive")
plt.xlabel('File repartition')
plt.ylabel('Cosine Distance')
dn = dendrogram(Z, labels = labels, leaf_rotation=90)
plt.xticks(fontsize=12,)
plt.savefig(f'{img_path}/dendrogram_clustering_label_digestive.pdf')

# %%
len(files_lab_l)
# Out:
# 89

# %%
hcl_labels = hcl.fcluster(Z, t=1.4, criterion='distance')

# %%
# df.sample(5)
print(max(hcl_labels))
# Out:
# 3

# %%
for i in range(len(labels)):
    idx = dn['leaves'][i]
    print(labels[idx],"\t Group :", hcl_labels[idx])
    print('TERMS')
    print(df_lab[df_lab["source"]==labels[idx]].term.tolist())
# Out:
# CRH_taka_sample_40.ann 	 Group : 1
# TERMS
# ['gastrite a helicobacter pylori']
# CRH_taka_sample_23.ann 	 Group : 1
# TERMS
# ['gastrite a helicobacter pylori']
# CRH_scl_sample_26.ann 	 Group : 1
# TERMS
# ['polypose colique', 'oesophagite', "akinesie de l'oesophage", 'incontinence anale', "dilatation de l'oesophage stable", 'incontinence fecale secondaire', 'malabsorption', 'poic tres severe', 'pseudoobstruction intestinale', 'syndrome subocclusif traite par sonde nasogastrique et sandostatine avec une evolution favorable', 'distension du grele central', 'pullulation microbienne du grele', 'atteinte cardiaque digestive basse severe', 'pullulation microbienne', 'hernie hiatale', 'erosions de d2', 'dyssynergie abdominoperineale de type 1', 'sclerodermie systemique de forme cutanee diffuse avec atteinte severe notamment au plan cardiaque et digestif', 'syndrome subocclusif', 'hypotonie du muscle puborectal', 'aggravation des diarrhees', 'augmentation diarrhee', 'aggravation atteinte digestive avec augmentation diarrhee, sous cellcept', 'atteinte digestive severe', '5 selles par jour']
# CRH_scl_sample_47.ann 	 Group : 1
# TERMS
# ['pseudoobstruction intestinale', 'oesophagite', 'syndrome subocclusif avait ete traite par sonde nasogastrique et sandostatine avec une evolution favorable', "akinesie de l'oesophage", 'incontinence anale', "dilatation de l'oesophage stable", 'incontinence fecale secondaire', 'polypose colique', 'rgo', 'pseudoobstruction intestinale', 'hernie hiatale', 'dyssynergie abdominoperineale de type 1', 'atteinte digestive severe', 'syndrome subocclusif', 'pseudoobstruction intestinale sur sclerodermie']
# CRH_scl_sample_46.ann 	 Group : 1
# TERMS
# ['rgo', 'polypose colique', 'pseudoobstruction intestinale', 'pseudoobstruction intestinale', 'oesophagite', 'syndrome subocclusif', "akinesie de l'oesophage", 'incontinence anale', "dilatation de l'oesophage stable", 'incontinence fecale secondaire', 'foie micronodulaire stable', 'majoration de la dilatation des anses greles', 'foie micronodulaire', 'foie micronodulaire, de contours reguliers', 'dilatation des anses greles', 'persistance de la distension du grele centrale', 'hernie hiatale', 'dyssynergie abdominoperineale de type 1', 'atteinte digestive severe', 'epanchement intraperitoneal faible abondance', 'pseudoobstruction intestinale sur sclerodermie']
# CRH_lupus_sample_29.ann 	 Group : 1
# TERMS
# ['diverticulose colique non compliquee']
# CRH_scl_sample_12.ann 	 Group : 1
# TERMS
# ['syndrome crest', 'syndrome crest', 'incontinence fecale', 'diverticulose sigmoidienne', 'discrete gastrite fundique congestive', 'syndrome crest incomplet', 'hypotonie du sphincter anal', 'ruptures  sphincters interne et externe']
# CRH_taka_sample_7.ann 	 Group : 1
# TERMS
# ["ulcere bulbaire traite par clip d'evolution favorable", 'ulcere bulbaire']
# CRH_lupus_sample_27.ann 	 Group : 1
# TERMS
# ['antrite nodulaire', 'mpinime hernie hiatale', 'hernie hiatale']
# CRH_scl_sample_38.ann 	 Group : 1
# TERMS
# ['reflux gastrooesophagien', 'oesophagite candidosique', 'peritonite a s epidermidis, a haemolyticus et bacteroides fragilis', 'oesophagite', 'oesophagite grade c candidosique', 'oesophagite de grade c', 'peritonite', 'syndrome du compartiment abdominal', 'syndrome du compartiment abdominal', 'oesophagite avec des ulcerations non specifiques', 'evisceration liee a une desunion de la partie inferieure de la cicatrice', 'evisceration', "recidive d'evisceration", 'amelioration de la dysphagie', 'subocclusion intestinale', 'subocclusion du grele sur obstacle progressif ileal', 'petit epanchement intraperitoneal pelvien', 'atteinte digestive']
# CRH_sapl_sample_10.ann 	 Group : 1
# TERMS
# ['oesophagite peptique de garde b', 'fibrose retro peritoneale', "hypotonie du sphincter inferieur de l'oesophage", 'fibrose retroperitoneale', 'oesophagite peptique']
# CRH_sapl_sample_19.ann 	 Group : 1
# TERMS
# ['diverticulose sigmoidienne', 'oesophagite grade i', 'oesophagite', 'foie dysmorphique', 'hernie hiatale', 'bulbite', 'bulbite erythemateuse']
# CRH_scl_sample_3.ann 	 Group : 1
# TERMS
# ['rgo', 'antrite severe en rayon de roue', 'dysphagie']
# CRH_scl_sample_20.ann 	 Group : 1
# TERMS
# ['rgo', 'metastatique osseux, hepatique', 'rgo stable']
# CRH_scl_sample_10.ann 	 Group : 1
# TERMS
# ['gastroparesie', 'rgo', 'arret du cellcept pour mauvaise tolerance digestive']
# CRH_taka_sample_48.ann 	 Group : 1
# TERMS
# ['rgo', 'rectorragies de sang rouge entourant les selles']
# CRH_scl_sample_14.ann 	 Group : 1
# TERMS
# ['oesophagite', 'rgo']
# CRH_scl_sample_9.ann 	 Group : 1
# TERMS
# ['reflux gastrooesophagien']
# CRH_scl_sample_37.ann 	 Group : 1
# TERMS
# ['endo brachyoesophage', 'oesophagienne endo brachyoesophage']
# CRH_scl_sample_17.ann 	 Group : 1
# TERMS
# ["gastrite chronique atrophiante de l'antre, active", 'gastrite superficielledu fundus', "oesophage d'aspect normal", 'rgo', 'metaplasie intestinale', 'antrite erythemateuse de faible intensite', 'discrete antrite chronique sans activite', 'foyer de metaplasie de type intestinal', 'muqueuse fundique dans les limites de la normale', 'atonie oesophagienne', 'parfois dysphagie aux solides']
# CRH_scl_sample_6.ann 	 Group : 1
# TERMS
# ['gastrite chronique helicobacter pylori', 'gastrite chronique active', 'gastrite chronique active antrale et fundique', 'minime gastrite antrale', 'dilatationoesophagienne minime', 'epigastralgies', 'pyrosis et sensation de blocage pharynge', 'gastrite chronique', 'gastrite chronique active avec infection a helicobacter pylori', 'constipation']
# CRH_sapl_sample_36.ann 	 Group : 1
# TERMS
# ['gastrite a h pylori', 'rgo', 'hernie de la ligne blanche']
# CRH_lupus_sample_4.ann 	 Group : 1
# TERMS
# ['gastrite', 'hp', 'polypes coliques', 'rgo', 'troubles de la deglutition', 'fausses routes', 'gastrite a helicobacter pylori', 'pyrosis']
# CRH_scl_sample_44.ann 	 Group : 1
# TERMS
# ['gastrite chronique a helicobacter pylori', "gastrite chronique non atrophique d'activite legere", 'gastroparesie symptomatique', 'rgo', 'gastrite fundique', 'gastrite chronique', 'gastroparesie majeure', 'gastrite', 'cholestase anicterique', 'cytolyse hepatique', 'vomissements post prandiaux precoces', 'hernie hiatale', 'vomissements postprandiaux systematiques', 'atteinte digestive de la sclerodermie', 'pyrosis']
# CRH_scl_sample_42.ann 	 Group : 1
# TERMS
# ['diarrhee malabsorptive', 'reflux gastro oesophagien augmentant progressivement', "diarrhee chronique depuis 2007, d'aggravation importante depuis 2 ans non glairosanglante mais malabsorptive", 'pseudoobstruction intestinale', 'oesophagite peptique grade a', 'rgo important', 'colopathie fonctionnelle', 'dysphagie', "diarrhee chronique depuis 2007, d'aggravation", 'koenig', 'debacle fecale', 'hernie hiatale']
# CRH_scl_sample_50.ann 	 Group : 1
# TERMS
# ['ulcere gastrique', 'rgo', 'stase stercorale', 'invagination jejuno jejunale', 'dysmotilite colique', 'evenement infectieux', 'sclerodermie systemique avec atteinte digestive', "dysmotilite colique stase stercorale sur l'ensemble du cadre colique et jejunale", 'diarrhees non glairo sanglantes', "stase stercorale sur l'ensemble du cadre colique", 'diarrhees', 'constipation', 'diminution du peristaltisme', 'vomissements']
# CRH_scl_sample_16.ann 	 Group : 1
# TERMS
# ['reflux gastrooesophagien', 'gastroparesie', 'oesophagite', 'colite a clostridium difficile', 'steatose hepatique non alcoolique', 'gastroparesie sclerodermique', 'gastroparesie probable aigue', 'vomissements noiratres', 'diarrhees nauseabondes', 'cicatrice', 'diarrhees aux antibiotiques', 'vomissements']
# CRH_taka_sample_47.ann 	 Group : 1
# TERMS
# ['gastrite antrale', 'hepatite b guerie', 'gastrite antrale', "gastrite chronique moderee de l'antre", 'hepatite b guerie', "infection ancienne par le virus de l'hepatite b"]
# CRH_scl_sample_45.ann 	 Group : 1
# TERMS
# ['rectorragie', 'gastrite antrale et fundique', 'reflux gastro oesophagien bien controle', 'cytolyses hepatique', 'quelques angiodysplasie colique']
# CRH_scl_sample_5.ann 	 Group : 1
# TERMS
# ['oesophagite a candida albicans', 'rgo', 'estomac pasteque', 'endobrachyoesophage', 'atonie oesophagienne']
# CRH_scl_sample_52.ann 	 Group : 1
# TERMS
# ['reflux gastrooesophagien', 'oesophagite peptique de stade 2', 'rgo', 'distension oesophagienne avec stase liquidienne', 'saignement digestif', 'angiodysplasies rectales']
# CRH_scl_sample_7.ann 	 Group : 2
# TERMS
# ['episode de diarrhee']
# CRH_sapl_sample_6.ann 	 Group : 2
# TERMS
# ['candidose oesphagienne', 'episode de diarrhee']
# CRH_sapl_sample_51.ann 	 Group : 2
# TERMS
# ['diarrhees', 'infection a clostridium difficile']
# CRH_sapl_sample_21.ann 	 Group : 2
# TERMS
# ['augmentation des marqueurs et de la lesion hepatique', 'metastases hepatique ganglionnaire', 'hernie inguinale', 'adenocarcinome moyennement differencie du haut rectum', 'diarrhee 78 sellesj, liquidiennes', '78 selles liquidiennes', 'adenocarcinome moyennement differencie du haut rectum, pt3 n2a', 'diarrhee importante choleriforme', 'diarrhee', 'recidive hepatique', 'cancer du haut rectum metastatique', 'episodes de diarrhees', 'infection bacterienne colique', 'diarrhees']
# CRH_taka_sample_31.ann 	 Group : 2
# TERMS
# ['gastro enterite']
# CRH_lupus_sample_30.ann 	 Group : 2
# TERMS
# ['cholecystite']
# CRH_lupus_sample_2.ann 	 Group : 2
# TERMS
# ['colite a']
# CRH_sapl_sample_27.ann 	 Group : 2
# TERMS
# ['thrombose portale']
# CRH_sapl_sample_0.ann 	 Group : 2
# TERMS
# ['oesophagite', 'thrombose porte', 'ileite', 'candidose oesophagienne', 'candidose oesophagienne', 'thrombose portale', 'oesophagite candidosique a candida albicans']
# CRH_sapl_sample_16.ann 	 Group : 2
# TERMS
# ['colites infectieuses', 'colite a c difficile', 'thrombose portale', 'candidose oesophagienne recidivante', 'candidose oesophagienne', 'thrombose porte', 'ileite', 'colite a clostridium difficile', 'cytolyse hepatique fluctuante', 'hepatite medicamenteuse, attribuable a la colchicine', "hepatite d'activite minime", 'hepatite', 'hepatotoxicite', 'angiodysplasie jejunale', 'hepatite medicamenteuse']
# CRH_sapl_sample_5.ann 	 Group : 2
# TERMS
# ['colites infectieuses', 'colite a c difficile', 'thrombose portale', 'candidose oesophagienne recidivante', '3eme episode de candidose oesophagienne', 'thrombose porte', 'ileite', 'colite a clostridium difficile', 'cytolyse hepatique fluctuante', "hepatite d'activite minime", 'amelioration transitoire de la cytolyse', 'quelques necroses hepatocytaires', 'angiodysplasie jejunale', 'sporanox  hepatotoxicite', 'infections digestives', "quelques necroses hepatocytaires, pas de steatose, pas de ballonnisation hepatocytaire cet aspect est en faveur d'une origine medicamenteuse"]
# CRH_taka_sample_42.ann 	 Group : 2
# TERMS
# ['atteinte mesenterique']
# CRH_sapl_sample_38.ann 	 Group : 2
# TERMS
# ['colite infectieuse']
# CRH_lupus_sample_44.ann 	 Group : 2
# TERMS
# ['maladie de crohn', 'rectorragies minimes', 'maladie de crohn', 'kyste biliaire']
# CRH_taka_sample_37.ann 	 Group : 2
# TERMS
# ['rectocolite hemorragique', 'rectocolite hemorragique', 'rch', 'rch quiescentes']
# CRH_lupus_sample_10.ann 	 Group : 2
# TERMS
# ['hematemese', 'rectorragie', 'rectorragies']
# CRH_scl_sample_48.ann 	 Group : 2
# TERMS
# ['rgo est actuellement bien controle']
# CRH_lupus_sample_15_copy.ann 	 Group : 2
# TERMS
# ['gastroenterite']
# CRH_scl_sample_51.ann 	 Group : 2
# TERMS
# ['atteinte oesophagienne avec dyskinesie']
# CRH_lupus_sample_31.ann 	 Group : 2
# TERMS
# ['virose digestive']
# CRH_taka_sample_12.ann 	 Group : 2
# TERMS
# ['hemorroides', 'cholestase ggt isolee', 'maladie de takayasu diagnostiquee en 2012 avec atteinte digestive', 'atteinte digestive evolutive']
# CRH_taka_sample_39.ann 	 Group : 2
# TERMS
# ['hemorroides', 'maladie de takayasu diagnostiquee en 2012 avec atteinte digestive', 'atteinte digestive evolutive']
# CRH_sapl_sample_24.ann 	 Group : 2
# TERMS
# ['melena', 'diverticules sigmoidiens', 'hemorragies digestives', 'hemorragie digestive haute', 'hemorragie digestive', 'hemorragie digestive', 'deglobulisation digestive', 'saignement digestif']
# CRH_taka_sample_35.ann 	 Group : 2
# TERMS
# ['atteinte digestive vasculaire du takayasu', 'stabilite atteintes vasculaires digestives']
# CRH_lupus_sample_45.ann 	 Group : 2
# TERMS
# ['epigastralgies']
# CRH_lupus_sample_19.ann 	 Group : 2
# TERMS
# ['crise hemorroidaire']
# CRH_lupus_sample_52.ann 	 Group : 2
# TERMS
# ['hemorroides', 'epigastralgies soulagees']
# CRH_sapl_sample_1.ann 	 Group : 2
# TERMS
# ['troubles de la deglutition', 'aggravation de troubles de la deglutitions', 'troubles de la deglutition', 'troubles de la deglutition fluctuants', 'fausse route', 'dysphagie majeure', "troubles de la deglutition depuis plusieurs mois, a l'eau et aux solides", 'fausses routes']
# CRH_sapl_sample_18.ann 	 Group : 2
# TERMS
# ['fausses routes', 'troubles de la deglutition', 'constipation', 'nombreuses fausses routes']
# CRH_scl_sample_40.ann 	 Group : 2
# TERMS
# ['ulcere gastroduodenal', "gastrite chronique d'intensite legere a helicobacter pylori", 'trouble de la deglutition']
# CRH_sapl_sample_4.ann 	 Group : 2
# TERMS
# ['hepatite c chronique', 'trouble de la deglutition', 'occlusion sur bride']
# CRH_taka_sample_13.ann 	 Group : 2
# TERMS
# ['nausees sous methotrexate']
# CRH_sapl_sample_20.ann 	 Group : 2
# TERMS
# ['chimiotherapie taxotere hormonotherapie femara avec toxicite hepatique']
# CRH_lupus_sample_16.ann 	 Group : 2
# TERMS
# ['reflux gastroesophagien']
# CRH_scl_sample_19.ann 	 Group : 2
# TERMS
# ['reflux gastro oesophagien', 'antibiotherapietronquee a domicile intolerance digestive', 'intolerance au valium vomissements']
# CRH_lupus_sample_12.ann 	 Group : 2
# TERMS
# ['ileite terminale', 'intolerance digestive au contramal', 'intolerance digestive au contramal codeine']
# CRH_lupus_sample_20.ann 	 Group : 3
# TERMS
# ['hepatite amibienne']
# CRH_scl_sample_18.ann 	 Group : 3
# TERMS
# ['hyperamylasemie']
# CRH_scl_sample_29.ann 	 Group : 3
# TERMS
# ['hyperamylasemie', 'hepatite b 1989, guerie']
# CRH_scl_sample_0.ann 	 Group : 3
# TERMS
# ['hepatite b 1989, guerie', 'hyperamylasemie']
# CRH_lupus_sample_28.ann 	 Group : 3
# TERMS
# ['stabilite du nodule surrenalien']
# CRH_sapl_sample_39.ann 	 Group : 3
# TERMS
# ['cholestase en regression']
# CRH_sapl_sample_14.ann 	 Group : 3
# TERMS
# ['hepatopathie kystique chronique']
# CRH_taka_sample_29.ann 	 Group : 3
# TERMS
# ['hepatopathie']
# CRH_scl_sample_30.ann 	 Group : 3
# TERMS
# ['lithiase vesiculaire non compliquee', 'colique hepatobiliaire', 'discrete beance oesophagienne']
# CRH_sapl_sample_52.ann 	 Group : 3
# TERMS
# ['colite transverse', "regression partielle de l'aspect de colite focale transverse", 'volumineuses adenomegalies coeliaques a centre necrotique presentant un contact pancreatique', "amelioration d'une cytolyse hepatique", 'adenopathie necrotique peripancreatique', 'adenomegalies coeliaques au centre necrotique au contact du pancreas', 'atteinte renale hta, proteinurie, augmentation de la creatinine, cutanee, thromboembolique arterielle ep, renale et veineuse phlebite surale, et digestive', 'ganglion necrotique peripancreatique', 'adenomegalies coeliaques au centre necrotique', 'digestive']
# CRH_sapl_sample_33.ann 	 Group : 3
# TERMS
# ['hepatite c', "pancreatites aigues a repetition d'origine ethylique", 'pancreatite aigue balthazar c', 'hernie inguinale', 'lithiase vesiculaire', "pancreatite a repetition d'origine ethylique", 'atrophie globale du parenchyme pancreatique', 'parenchyme pancreatique siege de multiples calcifications']
# CRH_taka_sample_19.ann 	 Group : 3
# TERMS
# ['pancreatite aigue balthazar c', 'malabsorption sequellaire de la pancreatite aigue', 'pancreatite aigue', 'hypophosphatemie secondaire a une malabsorption']
# CRH_taka_sample_26.ann 	 Group : 3
# TERMS
# ['formation hyperechogene hepatique du segment vii']
# CRH_lupus_sample_0.ann 	 Group : 3
# TERMS
# ['epanchement libre peri hepatique', 'occlusion grelique', 'distension grelique', 'epanchement libre perihepatique']
# CRH_scl_sample_39.ann 	 Group : 3
# TERMS
# ['steatose hepatique', 'atrophie pancreatique', 'cytolyse hepatique', 'steatose hepatique', 'adenome tubulovilleux en dysplasie de haut grade colique', 'hepatite b ancienne', 'adenome tubulo villeux en dysplasie de haut grade']
# CRH_sapl_sample_25.ann 	 Group : 3
# TERMS
# ['atteinte renale, hepatique', 'atteinte renale, hepatique, gastrique', 'carcinome epidermoide de la marge anale']
# CRH_scl_sample_21.ann 	 Group : 3
# TERMS
# ['varices oesophagiennes', 'gastrite', 'hepatite b ancienne', 'reflux gastro oesophagien', 'majoration de la cholestase', 'kystes biliaires', 'paquet hemorroidaire externe']
# CRH_taka_sample_38.ann 	 Group : 3
# TERMS
# ['hepatite b chronique', 'hepatite b chronique', "atteinte des branches de division de l'artere hepatique commune", 'cytolyse hepatique', 'amelioration hepatique', 'maladie de takayasu avec atteinte cerebrale et digestive', 'cytolyse', 'angor mesenterique', 'angor mesenterique invalidant', 'angor mesenterique severe', 'arterite severe diffuse abdominale', "anevrisme fusiforme de 5 mm de la branche droite de l'artere hepatique"]
# CRH_sapl_sample_3.ann 	 Group : 3
# TERMS
# ['cavernome portal', 'hernie inguinale', 'thrombose portale', 'cavernome portal', 'perturbations du bilan hepatique', 'perturbation du bilan hepatique', 'biliopathie portale', 'maladie porto sinusoidale', 'sclerose hepato portale', 'perforation grelique', 'compression des voies biliaires', 'htp non cirrhotique', 'htp', 'sclerose hepatoportale', 'selle diarrheique', 'choc septique a point de depart digestif', 'cholestase non icterique', 'hernie hiatale', 'complications digestives']
# CRH_scl_sample_24.ann 	 Group : 3
# TERMS
# ['steatose majeure', 'cytolyse hepatique', 'cholestase anicterique', 'hemochromatose avec surcharge hepatique', 'gvh hepatique aigue', 'decompensation oedematoascitique', 'gvh digestive', 'legere aggravation avec cytolyse', 'perturbations du bhc', 'ductopenie sur 3 espaces portes', 'ductopenie', 'gvh digestive prouvee histologiquement', 'cytolyse en amelioration', 'cholestase moderee centrolobulaire', 'gradient de pression intrahepatique', 'htp majeure', 'pbh hepatique  gvh']
# CRH_lupus_sample_9.ann 	 Group : 3
# TERMS
# ['cytolyse hepatique chronique', 'dysmorphie hepatique', 'granulomes hepatiques', 'brulure epigastriques', 'epaississement de la distalite des branches de division intrahepatiques', 'hamartome biliairehepatique']
# CRH_lupus_sample_18.ann 	 Group : 3
# TERMS
# ['cholestase icterique', 'cytolyse hepatique', 'calculs intrahepatiques', 'ascite', 'cytolyse', 'lithiases branches droite et gauche intrahepatiques']

# %%
#from easynmt import EasyNMT, models
# model = EasyNMT('opus-mt')
# model_fr_en = EasyNMT(translator = models.AutoModel('opus-mt-fr-en'))

# %%
dict_cluster_l = {}
size_group = {}
text_by_group = {}

for i in range(max(hcl_labels)):
    group_term = []
    size = 0
    for a,b in zip(files_lab_l, hcl_labels):
        if b==i+1:
            #print(f"{a}, group {b}")
            #print(df_lab[df_lab["source"]==a].term)
            translated_terms = model_fr_en.translate(df_lab[df_lab["source"]==a].term.tolist(), 
                                                     source_lang = 'fr',target_lang='en')
            group_term.append(translated_terms)
            dict_cluster_l[a] = b
            size += 1
    size_group[i] = size
    print(f"\n -- group {i}, with n = {size} elements")
    text_by_group[i] = ' '.join(flatten(group_term))
# Out:
#  -- group 0, with n = 31 elements
#
#  -- group 1, with n = 36 elements
#
#  -- group 2, with n = 22 elements

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

idx_group = 0


text = text_by_group[idx_group]
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["sur","du","en","le","les","par","clinique","de",'stabilité','au niveau',"gauche",'droite',"type",
                  'syndrome',"du", "et","amélioration", "diminution","majoration","stable", 'sévère',
                  "persistance", "bilatérale","maladie", "anti", "auto", 'de forme', 'la', "à", 
                  "des", "Ac","connue","au",'d',"atteinte", "non","avec", "l'hôpital", "est","aux", 'pour'])

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords = stopwords, max_font_size=50, max_words=30, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"clustering for label {label}_group_{idx_group}, for n = {size_group[idx_group]}")
plt.show()

# Save the image in the img folder:
wordcloud.to_file(f'{img_path}/wordcloud_annot_group_{idx_group}label_{label}.pdf')

# %%
idx_group = 1
text = text_by_group[idx_group]

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords = stopwords, max_font_size=50, max_words=30, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"clustering for label {label}_group_{idx_group}, for n = {size_group[idx_group]}")
plt.show()

# Save the image in the img folder:
wordcloud.to_file(f'{img_path}/wordcloud_annot_group_{idx_group}label_{label}.pdf')

# %%
idx_group = 2
text = text_by_group[idx_group]

# Create and generate a word cloud image:
wordcloud = WordCloud(stopwords = stopwords, max_font_size=50, max_words=30, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title(f"clustering for label {label}_group_{idx_group}, for n = {size_group[idx_group]}")
plt.show()

# Save the image in the img folder:
wordcloud.to_file(f'{img_path}/wordcloud_annot_group_{idx_group}label_{label}.pdf')
